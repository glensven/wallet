# %%
pip install dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Glen\anaconda3\envs\eth\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Glen\\AppData\\Local\\Temp\\pip-install-a0ya8kdd\\dotenv_18195f2bda0745038f1878959908f0f0\\setup.py'"'"'; __file__='"'"'C:\\Users\\Glen\\AppData\\Local\\Temp\\pip-install-a0ya8kdd\\dotenv_18195f2bda0745038f1878959908f0f0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Glen\AppData\Local\Temp\pip-pip-egg-info-hatszfi7'
#          cwd: C:\Users\Glen\AppData\Local\Temp\pip-install-a0ya8kdd\dotenv_18195f2bda0745038f1878959908f0f0\
#     Complete output (1589 lines):
#         ERROR: Command errored out with exit status 1:
# ...
